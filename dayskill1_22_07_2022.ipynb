# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bc6aaa71-ca56-4812-9cc3-875f17e1c553" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bc6aaa71-ca56-4812-9cc3-875f17e1c553">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving heart_statlog_cleveland_hungary_final.csv to heart_statlog_cleveland_hungary_final.csv

# %%
import pandas as pd
import io
df = pd.read_csv(io.BytesIO(uploaded['heart_statlog_cleveland_hungary_final.csv']))

# %%
print(df)
# Out:
#       age  sex  chest pain type  resting bp s  cholesterol  \
# 0      40    1                2           140          289
# 1      49    0                3           160          180
# 2      37    1                2           130          283
# 3      48    0                4           138          214
# 4      54    1                3           150          195
# ...   ...  ...              ...           ...          ...
# 1185   45    1                1           110          264
# 1186   68    1                4           144          193
# 1187   57    1                4           130          131
# 1188   57    0                2           130          236
# 1189   38    1                3           138          175
#
#       fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# 0                       0            0             172                0
# 1                       0            0             156                0
# ...

# %%
df.head(5)
# Out:
#    age  sex  chest pain type  resting bp s  cholesterol  fasting blood sugar  \
# 0   40    1                2           140          289                    0
# 1   49    0                3           160          180                    0
# 2   37    1                2           130          283                    0
# 3   48    0                4           138          214                    0
# 4   54    1                3           150          195                    0
#
#    resting ecg  max heart rate  exercise angina  oldpeak  ST slope  target
# 0            0             172                0      0.0         1       0
# 1            0             156                0      1.0         2       1
# 2            1              98                0      0.0         1       0
# 3            0             108                1      1.5         2       1
# 4            0             122                0      0.0         1       0

# %%
df.tail(5)
# Out:
#       age  sex  chest pain type  resting bp s  cholesterol  \
# 1185   45    1                1           110          264
# 1186   68    1                4           144          193
# 1187   57    1                4           130          131
# 1188   57    0                2           130          236
# 1189   38    1                3           138          175
#
#       fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# 1185                    0            0             132                0
# 1186                    1            0             141                0
# 1187                    0            0             115                1
# 1188                    0            2             174                0
# 1189                    0            0             173                0
#
#       oldpeak  ST slope  target
# 1185      1.2         2       1
# 1186      3.4         2       1
# 1187      1.2         2       1
# 1188      0.0         2       1
# ...

# %%
df.dtypes
# Out:
# age                      int64
# sex                      int64
# chest pain type          int64
# resting bp s             int64
# cholesterol              int64
# fasting blood sugar      int64
# resting ecg              int64
# max heart rate           int64
# exercise angina          int64
# oldpeak                float64
# ST slope                 int64
# target                   int64
# dtype: object
